# %% [markdown]
# Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import os 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing Dataset

# %%
df_item = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_order_items_dataset.csv")
df_customer = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_customers_dataset.csv")
df_geolocation = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_geolocation_dataset.csv")
df_payments = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_order_payments_dataset.csv")
df_reviews = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_order_reviews_dataset.csv")
df_orders = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_orders_dataset.csv")
df_product = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_products_dataset.csv")
df_seller = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\olist_sellers_dataset.csv")
df_product_category = pd.read_csv(r"C:\Users\Administrator\Desktop\sales and customer analysis\EDA---Sales-and-Customer-Analysis\Dataset\product_category_name_translation.csv")

# %%
# Out:
# (112650, 7)
